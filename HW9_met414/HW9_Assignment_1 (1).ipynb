# %%
import pylab as pl
import pandas as pd
import geopandas as gp
import numpy as np
import scipy.stats
import os
import json
from pandas.tools.plotting import scatter_matrix
import statsmodels.api as sm
#lowercase ols
import statsmodels.formula.api as smf
#uppercase OLS
import datetime as dt
import collections
import operator

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Task 1: Event Detection

# %%
os.system(os.getenv("PUIDATA")+"/MTA_Fare.npy")
# Out:
# 32256

# %%
mtaRides = np.load(os.getenv("PUIDATA")+"/MTA_Fare.npy")
#calling data uploaded into PUIDATA

# %%
mtaRides.shape #shape of the 3D array
# Out:
# (600, 23, 194)

# %%
mtaRides.flatten().shape #flatten test
# Out:
# (2677200,)

# %%
ridetype = np.array(['10t', '14d', '1d', '2t', '30d', '7d', 'ada', 'afas', 'exp','ez',
            'ff','mc','mr','month','rfm','rr','sen','spec','tcmc','t',
            'umlim','xbus','stud'])

# %%
ridetype.shape
# Out:
# (23,)

# %%
np.nansum(mtaRides) #nansum before converting -1 to NaN
# Out:
# 5776932312

# %%
mtaRides = mtaRides.astype('float')
mtaRides[mtaRides == -1] = np.nan
# converting all -1 to NaN

# %%
np.nansum(mtaRides) #nansum after converting -1 to nan
# Out:
# 5777581875.0

# %%
print (mtaRides.shape)

mta_allsum = np.nansum(mtaRides, axis=0)
print (mta_allsum.shape)

mta_allsum2 = np.nansum(mtaRides, axis=1)
print (mta_allsum2.shape)

mta_allsum3 = np.array(mta_allsum).reshape(194,23)
print(mta_allsum3.shape)

#600 stations
#23 card types
#194 weeks
#Here I am testing the shape of arrays, collapsing different sides
# Out:
# (600, 23, 194)
# (23, 194)
# (600, 194)
# (194, 23)

# %%
ridesbyweek = np.nansum(mta_allsum, axis=0)
ridesbyweek.shape
# Out:
# (194,)

# %%
pl.plot(ridesbyweek)
pl.xlabel('Weeks')
pl.ylabel('Rides')
pl.title('Total Subway Rides by Week')
pl.show()

# %% [markdown]
# ## Figure 1:
# The above plot shows the sum of all subway rides, by week, over a period of 194 weeks from 5/21/10 through 2/21/14.

# %%
pl.plot(mta_allsum)
pl.show()

#testing a plot for another array

# %%
np.nanmean(ridesbyweek)
# Out:
# 29781349.87113402

# %%
np.nansum(ridesbyweek)
# Out:
# 5777581875.0

# %%
np.nanstd(ridesbyweek, axis=0)
# Out:
# 2983960.421700886

# %%
print ("mean rides per week {:.2f}".format(np.nanmean(ridesbyweek)))
print ("stdev rides per week {:.2f}".format(np.nanstd(ridesbyweek)))
thresholds = [np.nanmean(ridesbyweek) + 3 * np.nanstd(ridesbyweek), 
              np.nanmean(ridesbyweek) - 3 * np.nanstd(ridesbyweek)]
print ("3-sigma thresholds {:.2f} {:.2f}".format(*thresholds))
print ("earliest datapoint", min(ridesbyweek))
#calculating the upper and lower thresholds (-3,+3 stdev)
# Out:
# mean rides per week 29781349.87
# stdev rides per week 2983960.42
# 3-sigma thresholds 38733231.14 20829468.61
# ('earliest datapoint', 5218686.0)

# %%
# Finding the the place of the minimum value in the ridesbyweek array
leastrides = np.where(ridesbyweek==ridesbyweek.min())
print leastrides
# Out:
# (array([126]),)

# %%
weekinterval = pd.date_range('5/21/2010', periods=194, freq='W')
weekinterval
weekinterval[127]
# the code generates the 126 item in the array as the min, which is the week of 10-22-12,
# however, history shows that NY Gov. Cuomo shut down the subways on 10-28-12. For historical
# accuracy, I will proceed with 10-28-12, which is the 127 item in the array
# Out:
# Timestamp('2012-10-28 00:00:00', offset='W-SUN')

# %%
pl.plot(weekinterval,(ridesbyweek),'b', alpha=0.7)
pl.xticks(rotation='65')
pl.legend(loc='upper left')
#plot testing the weekinterval
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
pl.plot(weekinterval,(ridesbyweek),'b', alpha=0.7)
pl.xticks(rotation='65')

pl.plot((min(weekinterval), max(weekinterval)),((thresholds[0]),(thresholds[0])), color='y',
       label='Upper Threshold +3sigma = %.2f' % (thresholds[0]))
pl.plot((min(weekinterval), max(weekinterval)),((thresholds[1]),(thresholds[1])), color='r',
       label='Lower Threshold -3sigma = %.2f' % (thresholds[1]))

pl.xlabel('Weeks')
pl.ylabel('Rides')
pl.title('Total Subway Rides by Week')
pl.legend(loc='best', fontsize='small')

# %% [markdown]
# ## Figure 2:
# The above plot displays total subway rides by week for 194 weeks. The plot includes identifiers for upper and lower thresholds set at 3 standard deviations in both directions. There is only 1 event, taking place during the week of 10-21-12, which exceeds either threshold.

# %% [markdown]
# # Task 2: Popularity of Ridership Types

# %%
mta_allsum4 = mta_allsum.transpose()
mta_allsum4.shape
#chnaging shape of array
# Out:
# (194, 23)

# %%
#plot test
pl.plot(weekinterval, np.log10(pd.stats.moments.rolling_mean(mta_allsum4,10)))

pl.xlabel('Weeks')
pl.ylabel('Rides')
pl.xticks(rotation='65')
pl.title("Rolling Mean of Rides by Card Type")
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Figure 3
# The above plot displays the rolling mean of the subway rides by Card Type, of which there are 23, over a time period of 194 weeks

# %%
#plot test

pl.plot(weekinterval,(mta_allsum4))
pl.xticks(rotation='65')
pl.legend(loc='best')

# %%
cardtyperidesnozero = mta_allsum4[~((mta_allsum4 > 0))]
cardtyperidesnozero.shape
# Out:
# (304,)

# %%
#pl.plot(weekinterval,(pd.stats.moments.rolling_mean(cardtyperidesnozero,10)))

# %% [markdown]
# # Task 3

# %%
mtastationsum = mta_allsum2.transpose()
pl.plot(weekinterval, np.log10(mtastationsum))
pl.title('Total Rides Per Station by Week')
pl.xticks(rotation = '65')
pl.xlabel("Weeks")
pl.ylabel("Swipes (log10)")

# %%
pl.plot(np.abs(np.fft.rfft(mtastationsum)))
# Out:
# [<matplotlib.lines.Line2D at 0x7fc1a479c910>,
#  <matplotlib.lines.Line2D at 0x7fc1a479c290>,
#  <matplotlib.lines.Line2D at 0x7fc1c6499a10>,
#  <matplotlib.lines.Line2D at 0x7fc1778e1ad0>,
#  <matplotlib.lines.Line2D at 0x7fc1a469a050>,
#  <matplotlib.lines.Line2D at 0x7fc1a469a250>,
#  <matplotlib.lines.Line2D at 0x7fc1a469a450>,
#  <matplotlib.lines.Line2D at 0x7fc1a469a650>,
#  <matplotlib.lines.Line2D at 0x7fc1a469a850>,
#  <matplotlib.lines.Line2D at 0x7fc1a469aa50>,
#  <matplotlib.lines.Line2D at 0x7fc1a469ac50>,
#  <matplotlib.lines.Line2D at 0x7fc1a469ae50>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629090>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629290>,
#  <matplotlib.lines.Line2D at 0x7fc17794dd90>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629690>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629890>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629a90>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629c90>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629e90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46370d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4629490>,
#  <matplotlib.lines.Line2D at 0x7fc1a46374d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46376d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46378d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4637ad0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4637cd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4637ed0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46372d0>,
#  <matplotlib.lines.Line2D at 0x7fc1c64a5810>,
#  <matplotlib.lines.Line2D at 0x7fc1c64a5350>,
#  <matplotlib.lines.Line2D at 0x7fc1c64a5310>,
#  <matplotlib.lines.Line2D at 0x7fc1778a4610>,
#  <matplotlib.lines.Line2D at 0x7fc1a4726950>,
#  <matplotlib.lines.Line2D at 0x7fc1a4726610>,
#  <matplotlib.lines.Line2D at 0x7fc1c64a5950>,
#  <matplotlib.lines.Line2D at 0x7fc1a6d14650>,
#  <matplotlib.lines.Line2D at 0x7fc1c3b38a90>,
#  <matplotlib.lines.Line2D at 0x7fc1a4647210>,
#  <matplotlib.lines.Line2D at 0x7fc1a46474d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4647590>,
#  <matplotlib.lines.Line2D at 0x7fc1a477ac90>,
#  <matplotlib.lines.Line2D at 0x7fc1a4726250>,
#  <matplotlib.lines.Line2D at 0x7fc1a4736550>,
#  <matplotlib.lines.Line2D at 0x7fc1a4736490>,
#  <matplotlib.lines.Line2D at 0x7fc1a4736790>,
#  <matplotlib.lines.Line2D at 0x7fc1a4736990>,
#  <matplotlib.lines.Line2D at 0x7fc1a4736b90>,
#  <matplotlib.lines.Line2D at 0x7fc1a4736d90>,
#  <matplotlib.lines.Line2D at 0x7fc1c64b5f90>,
#  <matplotlib.lines.Line2D at 0x7fc1c644c390>,
#  <matplotlib.lines.Line2D at 0x7fc1c644c1d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654210>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654310>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654410>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654510>,
#  <matplotlib.lines.Line2D at 0x7fc1a4736f90>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654710>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654810>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654910>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654a10>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654b10>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654c10>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654610>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654e10>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654f10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7050>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7150>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7250>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7350>,
#  <matplotlib.lines.Line2D at 0x7fc1a4654d10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7550>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7650>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7750>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7850>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7950>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7a50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7450>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7c50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7d50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7e50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7f50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5090>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5190>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e7b50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5390>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5490>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5590>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5690>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5790>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5890>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5290>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5a90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5b90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5c90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5d90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5e90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5f90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46f5990>,
#  <matplotlib.lines.Line2D at 0x7fc1a47011d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47012d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47013d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47014d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47015d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47016d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47010d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47018d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47019d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4701ad0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4701bd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4701cd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4701dd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a47017d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a4701fd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f110>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f210>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f310>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f410>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f510>,
#  <matplotlib.lines.Line2D at 0x7fc1a4701ed0>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f710>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f810>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f910>,
#  <matplotlib.lines.Line2D at 0x7fc1a470fa10>,
#  <matplotlib.lines.Line2D at 0x7fc1a470fb10>,
#  <matplotlib.lines.Line2D at 0x7fc1a470fc10>,
#  <matplotlib.lines.Line2D at 0x7fc1a470f610>,
#  <matplotlib.lines.Line2D at 0x7fc1a470fe10>,
#  <matplotlib.lines.Line2D at 0x7fc1a470ff10>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c050>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c150>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c250>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c350>,
#  <matplotlib.lines.Line2D at 0x7fc1a470fd10>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c550>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c650>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c750>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c850>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c950>,
#  <matplotlib.lines.Line2D at 0x7fc1a471ca50>,
#  <matplotlib.lines.Line2D at 0x7fc1a471c450>,
#  <matplotlib.lines.Line2D at 0x7fc1a471cc50>,
#  <matplotlib.lines.Line2D at 0x7fc1a471cd50>,
#  <matplotlib.lines.Line2D at 0x7fc1a471ce50>,
#  <matplotlib.lines.Line2D at 0x7fc1a471cf50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa090>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa190>,
#  <matplotlib.lines.Line2D at 0x7fc1a471cb50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa390>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa490>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa590>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa690>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa790>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa890>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa290>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aaa90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aab90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aac90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aad90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aae90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aaf90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45aa990>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b61d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b62d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b63d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b64d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b65d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b66d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b60d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b68d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b69d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b6ad0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b6bd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b6cd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b6dd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b67d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b6fd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6110>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6210>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6310>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6410>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6510>,
#  <matplotlib.lines.Line2D at 0x7fc1a45b6ed0>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6710>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6810>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6910>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6a10>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6b10>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6c10>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6610>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6e10>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6f10>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3050>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3150>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3250>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3350>,
#  <matplotlib.lines.Line2D at 0x7fc1a45c6d10>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3550>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3650>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3750>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3850>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3950>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3a50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3450>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3c50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3d50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3e50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3f50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0090>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0190>,
#  <matplotlib.lines.Line2D at 0x7fc1a45d3b50>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0390>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0490>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0590>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0690>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0790>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0890>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0290>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0a90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0b90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0c90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0d90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0e90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0f90>,
#  <matplotlib.lines.Line2D at 0x7fc1a45e0990>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad1d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad2d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad3d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad4d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad5d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad6d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad0d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad8d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad9d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46adad0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46adbd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46adcd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46addd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ad7d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46adfd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba110>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba210>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba310>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba410>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba510>,
#  <matplotlib.lines.Line2D at 0x7fc1a46aded0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba710>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba810>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba910>,
#  <matplotlib.lines.Line2D at 0x7fc1a46baa10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46bab10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46bac10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46ba610>,
#  <matplotlib.lines.Line2D at 0x7fc1a46bae10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46baf10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7050>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7150>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7250>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7350>,
#  <matplotlib.lines.Line2D at 0x7fc1a46bad10>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7550>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7650>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7750>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7850>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7950>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7a50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7450>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7c50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7d50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7e50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7f50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5090>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5190>,
#  <matplotlib.lines.Line2D at 0x7fc1a46c7b50>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5390>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5490>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5590>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5690>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5790>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5890>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5290>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5a90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5b90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5c90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5d90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5e90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5f90>,
#  <matplotlib.lines.Line2D at 0x7fc1a46d5990>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e21d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e22d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e23d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e24d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e25d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e26d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e20d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e28d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e29d0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e2ad0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e2bd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e2cd0>,
#  <matplotlib.lines.Line2D at 0x7fc1a46e2dd0>]

# %%
N = 194 #the length of your time series (the number of datapoints) maybe is 194?
d = 1.0/52.0 #1 per every 52 weeks

np.fft.rfftfreq(N, d)
# Out:
# array([  0.        ,   0.26804124,   0.53608247,   0.80412371,
#          1.07216495,   1.34020619,   1.60824742,   1.87628866,
#          2.1443299 ,   2.41237113,   2.68041237,   2.94845361,
#          3.21649485,   3.48453608,   3.75257732,   4.02061856,
#          4.28865979,   4.55670103,   4.82474227,   5.09278351,
#          5.36082474,   5.62886598,   5.89690722,   6.16494845,
#          6.43298969,   6.70103093,   6.96907216,   7.2371134 ,
#          7.50515464,   7.77319588,   8.04123711,   8.30927835,
#          8.57731959,   8.84536082,   9.11340206,   9.3814433 ,
#          9.64948454,   9.91752577,  10.18556701,  10.45360825,
#         10.72164948,  10.98969072,  11.25773196,  11.5257732 ,
#         11.79381443,  12.06185567,  12.32989691,  12.59793814,
#         12.86597938,  13.13402062,  13.40206186,  13.67010309,
#         13.93814433,  14.20618557,  14.4742268 ,  14.74226804,
#         15.01030928,  15.27835052,  15.54639175,  15.81443299,
#         16.08247423,  16.35051546,  16.6185567 ,  16.88659794,
#         17.15463918,  17.42268041,  17.69072165,  17.95876289,
#         18.22680412,  18.49484536,  18.7628866 ,  19.03092784,
#         19.29896907,  19.56701031,  19.83505155,  20.10309278,
#         20.37113402,  20.63917526,  20.90721649,  21.17525773,
#         21.44329897,  21.71134021,  21.97938144,  22.24742268,
#         22.51546392,  22.78350515,  23.05154639,  23.31958763,
#         23.58762887,  23.8556701 ,  24.12371134,  24.39175258,
#         24.65979381,  24.92783505,  25.19587629,  25.46391753,
#         25.73195876,  26.        ])

# %%
meanstation = np.nanmean(mtaRides, axis=1)
meanstation.shape
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:675: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
# (600, 194)

# %%
N = len(mtastationsum)
f = np.abs(np.fft.rfft(mta_allsum2))
fig=pl.figure(figsize=(15,5))
ax=fig.add_subplot(111)

maxweeks = {}

for k in range(len(mtastationsum)):
    ax.plot(np.fft.rfftfreq(N, 1)[1:], (f[k][1:]),'o', ms=5)
    ax.plot(np.fft.rfftfreq(N, 1)[1:], (f[k][1:]),'-')
    maxweeks[k]=((f[4]))


pl.xlabel("Frequency")
pl.ylabel("Power")
pl.title('Rider per station Power Spectrum')

# %%
f.shape
# Out:
# (600, 98)

# %%
len(maxweeks)
# Out:
# 194

# %%
locate_maxweeks = collections.Counter(maxweeks)
most_yearly_periodic_stations = []

for x in locate_maxweeks.most_common(4):
       testmaxweeks.append(k)

print ("The most yearly period stations are: " + str (testmaxweeks))
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-38-da3600a55c10> in <module>()
#       2 most_yearly_periodic_stations = []
#       3
# ----> 4 for x in locate_maxweeks.most_common(4):
#       5        testmaxweeks.append(k)
#       6
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/collections.pyc in most_common(self, n)
#     493         if n is None:
#     494             return sorted(self.iteritems(), key=_itemgetter(1), reverse=True)
# --> 495         return _heapq.nlargest(n, self.iteritems(), key=_itemgetter(1))
#     496
#     497     def elements(self):
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/heapq.pyc in nlargest(n, iterable, key)
#     468     in1, in2 = tee(iterable)
#     469     it = izip(imap(key, in1), count(0,-1), in2)             # decorate
# --> 470     result = _nlargest(n, it)
#     471     return map(itemgetter(2), result)                       # undecorate
#     472
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# I'm receiving an error when attempting to sort the dictionary "maxweeks" by values in order
# to generate the 4 weeks within the range thay illustrate the largest shifts.
